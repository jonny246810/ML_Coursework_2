# %%
# !git clone https://github.com/jonny246810/ML_Coursework_2
# Out:
# Cloning into 'ML_Coursework_2'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 34 (delta 7), reused 33 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 2.49 MiB | 14.83 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
cd ML_Coursework_2/
# Out:
# /content/ML_Coursework_2

# %%
# %run src/modified_implementation.ipynb
# Out:
# Using device: cpu
# 100%|██████████| 170M/170M [00:01<00:00, 102MB/s]
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 99.4MB/s]
# loaded standard ImageNet ResNet18
# embeddings shape: (50000, 512)
# Median k-distance: 0.5696
# Median k-distance: 0.5696
# KNN-Distance removed 3678 outliers (beyond 0.67 threshold).
# Reduced dimensions to 32 using PCA.
# clustering 46322 clean embeddings into 50 clusters
# calculating typicality across the top 50 clusters using KNN
# 50 images to be labeled
# final test acc using typiclust (50 labels): 39.13%
# KNN-Distance removed 3678 outliers (beyond 0.67 threshold).
# Reduced dimensions to 32 using PCA.
# clustering 46322 clean embeddings into 10 clusters
# calculating typicality across the top 10 clusters using KNN
# KNN-Distance removed 3678 outliers (beyond 0.67 threshold).
# Reduced dimensions to 32 using PCA.
# ...
