# %%
# !git clone https://github.com/jonny246810/ML_Coursework_2
# Out:
# Cloning into 'ML_Coursework_2'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 30 (delta 5), reused 30 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 2.49 MiB | 14.65 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
cd ML_Coursework_2/
# Out:
# /content/ML_Coursework_2

# %%
# %run src/original_implementation.ipynb
# Out:
# Project root: /content/ML_Coursework_2
# Configuration loaded from: /content/ML_Coursework_2/config/config.json
# Dataset root: /content/ML_Coursework_2/data
# Using device: cpu
# 100%|██████████| 170M/170M [00:02<00:00, 60.1MB/s]
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 114MB/s]
# loaded standard ImageNet ResNet18
# Embeddings shape: (50000, 512)
# Number of features: 512
# clustering 50000 embeddings into 50 clusters
# calculating typicality across the top 50 clusters using KNN
# 50 images to be labeled
# final test acc using typiclust (50 labels): 37.71%
# clustering 50000 embeddings into 10 clusters
# calculating typicality across the top 10 clusters using KNN
# clustering 50000 embeddings into 20 clusters
# calculating typicality across the top 20 clusters using KNN
# clustering 50000 embeddings into 30 clusters
# ...
